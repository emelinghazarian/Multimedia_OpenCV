# %%
import cv2 
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

def imshow(title = "", image = None):
    plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

img_rgb = cv.imread('C:/Users/Emelin/Desktop/images/airport.jpg')
#assert img_rgb is not None, "file could not be read, check with os.path.exists()"
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

height, width = img_rgb.shape[:2]

start_row, start_col = int(height * .23), int(width * .4)
end_row, end_col = int(height * .36), int(width * .5)
cropped = img_rgb[start_row:end_row , start_col:end_col]

copy = img_rgb.copy()
cv2.rectangle(copy, (start_col,start_row), (end_col,end_row), (0,255,255), 10)
imshow("Area we are cropping", copy)

template= cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)

imshow("Cropped Image", template) 
w, h = template.shape[::-1]
res = cv.matchTemplate(img_gray,template,cv.TM_CCOEFF_NORMED)
threshold = 0.5
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,0,255), 2)
cv.imwrite('res.png',img_rgb)

imshow("detected airplanes", img_rgb)

# %%
import cv2 
height_2, width_2 = template.shape[:2]

rotation_matrix_1 = cv2.getRotationMatrix2D((width_2/2, height_2/2), -180, 1)

rotated180 = cv2.warpAffine(template, rotation_matrix_1, (width_2, height_2))
imshow("Rotated -180 degrees", rotated180)
w2, h2 = rotated180.shape[::-1] 
res2 = cv.matchTemplate(img_gray,rotated180,cv.TM_CCOEFF_NORMED)
threshold = 0.4
loc2 = np.where( res2 >= threshold)
for pt in zip(*loc2[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w2, pt[1] + h2), (0,0,255), 2)
cv.imwrite('res.png',img_rgb)

imshow("Cropped Image", img_rgb)

# %%
height_2, width_2 = template.shape[:2]

rotation_matrix_2 = cv2.getRotationMatrix2D((width_2/2, height_2/2), 270, 1)

rotated270 = cv2.warpAffine(template, rotation_matrix_2, (width_2, height_2))
imshow("Rotated 270 degrees", rotated270)
w3, h3 = rotated270.shape[::-1] 
res3 = cv.matchTemplate(img_gray,rotated270,cv.TM_CCOEFF_NORMED)
threshold = 0.5
loc3 = np.where( res3 >= threshold)
for pt in zip(*loc3[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w3, pt[1] + h3), (0,0,255), 2)
cv.imwrite('res.png',img_rgb)

imshow("Cropped Image", img_rgb)

# %%
height_2, width_2 = template.shape[:2]

rotation_matrix_3 = cv2.getRotationMatrix2D((width_2/2, height_2/2), 90, 1)

rotated90 = cv2.warpAffine(template, rotation_matrix_3, (width_2, height_2))
imshow("Rotated 90 degrees", rotated90)
w4, h4 = rotated90.shape[::-1] 
res4 = cv.matchTemplate(img_gray,rotated90,cv.TM_CCOEFF_NORMED)
threshold = 0.48
loc4 = np.where( res4 >= threshold)
for pt in zip(*loc4[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w4, pt[1] + h4), (0,0,255), 2)
cv.imwrite('res.png',img_rgb)

imshow("Cropped Image", img_rgb)

# %%
img_scaled = cv2.resize(rotated180, (100,70), interpolation = cv2.INTER_AREA)
imshow("Scaling - Inter Area", img_scaled)
w5, h5 = img_scaled.shape[::-1] 
res5 = cv.matchTemplate(img_gray,img_scaled,cv.TM_CCOEFF_NORMED)
threshold = 0.5
loc5 = np.where( res5 >= threshold)
for pt in zip(*loc5[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w5, pt[1] + h5), (0,0,255), 2)
cv.imwrite('res.png',img_rgb)

imshow("Cropped Image", img_rgb)

# %%
height_2, width_2 = template.shape[:2]

rotation_matrix_6 = cv2.getRotationMatrix2D((width_2/2, height_2/2), 100, 1)

rotated100 = cv2.warpAffine(template, rotation_matrix_6, (width_2, height_2))

img_scaled = cv2.resize(rotated100, (110,80), interpolation = cv2.INTER_AREA)
imshow("Scaling - Inter Area", img_scaled)
w6, h6 = img_scaled.shape[::-1] 
res6 = cv.matchTemplate(img_gray,img_scaled,cv.TM_CCOEFF_NORMED)
threshold = 0.8
loc6 = np.where( res6 >= threshold)
for pt in zip(*loc6[::-1]):
    cv.rectangle(img_rgb, pt, (pt[0] + w6, pt[1] + h6), (0,0,255), 2)
cv.imwrite('res6.png',img_rgb)

imshow("Cropped Image", img_rgb)
